# %%
# Membuat nama band berdasarkan input pengguna

# %%
print("Halo, selamat datang di pembuat nama band!")
nama_kota = input("Masukkan nama kota tempat Anda lahir: ")
nama_hewan_peliharaan = input("Masukkan nama hewan peliharaan Anda: ")
print(f"Nama band Anda adalah: {nama_kota} {nama_hewan_peliharaan}")
# Out:
# Halo, selamat datang di pembuat nama band!
# Nama band Anda adalah: Kediri Bunny
